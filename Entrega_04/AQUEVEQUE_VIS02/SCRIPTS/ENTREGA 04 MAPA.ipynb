# %%
from google.colab import drive
drive.mount('/content/drive')

#IMPORTAR LIBRERIAS
import pandas as pd
import matplotlib.pyplot as plt

#CREAR DATA FRAME DE LA BASE DE DATOS (la base de datos anterior tuvo errores de formato que no me permitian trabajarla; encabezados de columnas largos, variables que no encontraba, etc.).
df = pd.read_csv("/content/drive/MyDrive/ENTREGA 4 - GATOS ENDEMICOS NGNF/GATOS-6.csv")

#CREAR SUB-DATA FRAME QUE CONTENGA LOS DATOS
felidae = df[ df["FAMILIA"] == "Felidae" ]

#DEL DF ANTERIOR NOS INTERESAN SUS CARACTERISTICAS CUALITATIVAS ¿Qué es cualitatibamente contable entre los gatos?
DENOMINACIÓN1 = felidae["NOMBRE COMUN"]
PESO = felidae["PESO"]
LONGITUD = felidae["LONGITUD"]
COLA = felidae["COLA"]
DENOMINACIÓN2 = felidae["NOMBRE CIENTIFICO"]
CARNIVOROS = felidae["ORDEN"]
MAMIFERO = felidae["CLASE"]
UBICACIÓN = felidae["UBICACIÓN"]


# CREAR GRÁFICO DE DISPERSIÓN Y LOS MARCADORES
plt.figure(figsize=(10, 6))
plt.scatter(DENOMINACIÓN1, PESO, label='PESO', color='red', marker='o')
plt.scatter(DENOMINACIÓN1, LONGITUD, label='LONGITUD', color='green', marker='s')
plt.scatter(DENOMINACIÓN1, COLA, label='COLA', color='blue', marker='^')

# Etiquetas de ambos ejes X e Y
plt.xlabel('DENOMINACIÓN', fontsize=12)
plt.ylabel('VALORES', fontsize=12)
plt.title('PESO, LONGITUD Y LARGO de la COLA de los felinos', fontsize=18)

# LEYENDA DEL GRÁFICO Y DISEÑO
plt.legend()
plt.xticks(rotation='vertical')
plt.tight_layout()
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#¿Qué hacer? con el resto de los datos cualitatativos: nombre cientifico, orden y clase
#¿Cómo trabajarlos para un gráfico?

# %%
#IMPORTAR LIBRERIAS
import pandas as pd
import matplotlib.pyplot as plt

#CREAR DATA FRAME DE LA BASE DE DATOS (la base de datos anterior tuvo errores de formato que no me permitian trabajarla; encabezados de columnas largos, variables que no encontraba, etc.).
df = pd.read_csv("/content/drive/MyDrive/ENTREGA 4 - GATOS ENDEMICOS NGNF/GATOS-6.csv")

#CREAR SUB-DATA FRAME QUE CONTENGA LOS DATOS
felidae = df[ df["FAMILIA"] == "Felidae" ]

#DEL DF ANTERIOR NOS INTERESAN SUS CARACTERISTICAS CUALITATIVAS ¿Qué es cualitatibamente contable entre los gatos?
DENOMINACIÓN1 = felidae["NOMBRE COMUN"]
PESO = felidae["PESO"]
LONGITUD = felidae["LONGITUD"]
COLA = felidae["COLA"]
DENOMINACIÓN2 = felidae["NOMBRE CIENTIFICO"]
CARNIVOROS = felidae["ORDEN"]
MAMIFERO = felidae["CLASE"]
UBICACIÓN = felidae["UBICACIÓN"]

#CREAR EL GRÁFICO
plt.figure(figsize=(10, 6))
plt.scatter(DENOMINACIÓN1, COLA, label='COLA', color='orange', marker='^')

#Etiquetas de ambos ejes X e Y
plt.xlabel('DENOMINACIÓN', fontsize=12)
plt.ylabel('VALORES', fontsize=12)
plt.title('LARGO COLA DE LOS FELINOS', fontsize=18)

# LEYENDA DEL GRÁFICO Y DISEÑO
plt.legend()
plt.xticks(rotation='vertical')
plt.tight_layout()
plt.show()

# %%
#IMPORTAR LIBRERIAS
import pandas as pd
import matplotlib.pyplot as plt

#CREAR DATA FRAME DE LA BASE DE DATOS (la base de datos anterior tuvo errores de formato que no me permitian trabajarla; encabezados de columnas largos, variables que no encontraba, etc.).
df = pd.read_csv("/content/drive/MyDrive/ENTREGA 4 - GATOS ENDEMICOS NGNF/GATOS-6.csv")

#CREAR SUB-DATA FRAME QUE CONTENGA LOS DATOS
felidae = df[ df["FAMILIA"] == "Felidae" ]

#DEL DF ANTERIOR NOS INTERESAN SUS CARACTERISTICAS CUALITATIVAS ¿Qué es cualitatibamente contable entre los gatos?
DENOMINACIÓN1 = felidae["NOMBRE COMUN"]
PESO = felidae["PESO"]
LONGITUD = felidae["LONGITUD"]
COLA = felidae["COLA"]
DENOMINACIÓN2 = felidae["NOMBRE CIENTIFICO"]
CARNIVOROS = felidae["ORDEN"]
MAMIFERO = felidae["CLASE"]
UBICACIÓN = felidae["UBICACIÓN"]

#CREAR EL GRÁFICO
plt.figure(figsize=(10, 6))
plt.scatter(DENOMINACIÓN1, UBICACIÓN, label='UBICACIÓN', color='orange', marker='^')

#Etiquetas de ambos ejes X e Y
plt.xlabel('DENOMINACIÓN', fontsize=12)
plt.ylabel('VALORES', fontsize=12)
plt.title('Ubicación de los felinos', fontsize=18)

# LEYENDA DEL GRÁFICO Y DISEÑO
plt.legend()
plt.xticks(rotation='vertical')
plt.tight_layout()
plt.show()
