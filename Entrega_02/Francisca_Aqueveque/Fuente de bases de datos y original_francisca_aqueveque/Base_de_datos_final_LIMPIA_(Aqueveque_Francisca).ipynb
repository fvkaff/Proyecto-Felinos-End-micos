# %% [markdown]
# IMPORTAR LIBRERIA Y ARCHIVO CSV

# %%
#Importar libreria
import pandas as pd
import numpy as np

datos = pd.read_csv('/content/drive/MyDrive/Excels Gatos Endemicos/ESPECIES (fran).csv')
print(datos)
# Out:
#       ID\nInven\ntario\nNa\ncio\nnal     NOMBRE CIENTÍFICO  \
# 0                             1828.0            Aa nervosa
# 1                             2814.0     Abrocoma bennetti
# 2                              766.0      Abrocoma cinerea
# 3                              773.0  Abrothrix longipilis
# 4                             1071.0    Acaena masafuerana
# ...                              ...                   ...
# 1449                             NaN  Xenospingus concolor
# 1450                           340.0        Yunquea tenzii
# 1451                           738.0        Zaedyus pichiy
# 1452                           795.0   Ziphius cavirostris
# 1453                          5439.0     Zostera chilensis
#
#                                            NOMBRE COMÚN  \
# 0                                                   NaN
# 1     ratón chinchilla común, ratón chinchilla de Be...
# 2     ratón chinchilla de cola corta, ratón chinchil...
# 3               ratón lanudo común, ratón de pelo largo
# 4
# ...                                                 ...
# 1449                                          pizarrita
# 1450                                            yunquea
# 1451                                              piche
# 1452                           ballena picuda de Cuvier
# 1453                                       pasto marino
#
#                                    SINONIMIA incompleta     REINO  \
# 0                                   Myrosmodes nervosa    Plantae
# 1                                                   NaN  Animalia
# 2                                                   NaN  Animalia
# 3                                     Akodon longipilis  Animalia
# 4                                                   NaN   Plantae
# ...                                                 ...       ...
# 1449                                                NaN  Animalia
# 1450                                                NaN   Plantae
# 1451                                  Euphractus pichiy  Animalia
# 1452  Aliama desmarestii; Aliama indica; Delphinorhy...  Animalia
# 1453  Heterozostera chilensis, Heterozostera nigrica...   Plantae
#
#      PHYLLUM /\nDIVISIÓN          CLASE          ORDEN      FAMILIA  \
# 0          Magnoliophyta     Liliopsida    Asparagales  Orchidaceae
# 1               Chordata       Mammalia       Rodentia  Abrocomidae
# 2               Chordata       Mammalia       Rodentia  Abrocomidae
# 3               Chordata       Mammalia       Rodentia      Muridae
# 4          Magnoliophyta  Magnoliopsida        Rosales     Rosaceae
# ...                  ...            ...            ...          ...
# 1449            Chordata           Aves  Passeriformes   Thraupidae
# 1450       Magnoliophyta  Magnoliopsida      Asterales   Asteraceae
# 1451            Chordata       Mammalia      Xenarthra  Dasypodidae
# 1452            Chordata       Mammalia        Cetacea    Ziphiidae
# 1453       Magnoliophyta  Magnoliopsida    Alismatales  Zosteraceae
#
#      HÁBITO \n(sólo plantas)  ...  \
# 0                     Hierba  ...
# 1                        NaN  ...
# 2                        NaN  ...
# 3                        NaN  ...
# 4                     Hierba  ...
# ...                      ...  ...
# 1449                     NaN  ...
# 1450                 Arbusto  ...
# 1451                     NaN  ...
# 1452                     NaN  ...
# 1453                  Hierba  ...
#
#      CATEGORÍA VIGENTE:\nCR = En peligro crítico\nDD = Datos insuficientes\nEN = En Peligro\nEW= Extinta en estado silvestre\nEX = Extinta\nFP = Fuera de Peligro\nIC = Insuficientemente Conocida\nLC = Preocupación menor\nNT = Casi amenazada\nR  = Rara\nVU = Vulnerable  \
# 0                                                    VU
# 1                                                    LC
# 2                                                    LC
# 3                                                    LC
# 4                                                    CR
# ...                                                 ...
# 1449                                                 NT
# 1450                                               EN-R
# 1451                                                 NT
# 1452                                                 LC
# 1453                                                 EN
#
#      FUENTE DE CATEGORÍA VIGENTE:\nCAZA  = Reglamento Ley de CAZA\nRCE = Reglamento de Clasificación Especies.  \
# 0                                                   RCE
# 1                                                   RCE
# 2                                                   RCE
# 3                                                   RCE
# 4                                                   RCE
# ...                                                 ...
# 1449                                                RCE
# 1450                                                RCE
# 1451                                                RCE
# 1452                                                RCE
# 1453                                                RCE
#
#      Criterio clasificación para especies RCE Vigentes  \
# 0                                         VU B1ab(iii)
# 1                                                   --
# 2                                                   --
# 3                                                   --
# 4                                CR B1ab(iii)+2ab(iii)
# ...                                                ...
# 1449                                                --
# 1450                          EN B1ab(iii)+2ab(iii); D
# 1451                       NT [Rebajado desde VU A2de]
# 1452                                                --
# 1453                             EN B1ab(iii)+2ab(iii)
#
#      NÚMERO PROCESO RCE  \nse clasificó categoría Vigente  \
# 0                                                     6
# 1                                                    12
# 2                                                    15
# 3                                                     8
# 4                                                     5
# ...                                                 ...
# 1449                                                 17
# 1450                                                  4
# 1451                                                 11
# 1452                                                 13
# 1453                                             9 y 17
#
#      REFERENCIA o DECRETO\nCategoría Vigente  \
# 0                             DS 41/2011 MMA
# 1                             DS 16/2016 MMA
# 2                             DS 23/2019 MMA
# 3                             DS 19/2012 MMA
# 4                             DS 33/2011 MMA
# ...                                      ...
# 1449                          DS 44/2021 MMA
# 1450                   DS 23/2009 MINSEGPRES
# 1451                          DS 38/2015 MMA
# 1452                          DS 06/2017 MMA
# 1453                          DS 44/2021 MMA
#
#      Categoría ANTERIOR a RCE actual\n(NO VIGENTE)\nBol_47 = Boletín 47 MNHN\nCAZA  = Reglamento Ley de CAZA\nL_Rojo_Flora = Libro Rojo de flora\nL_Rojo_Vert = Libro Rojo de vertebrados\nNúñez et al. 1997 = Reunión de herpetólogos\nYáñez et al. 1997 = Reunión especialistas mamíferos acuáticos\nRCE = Reglamento de Clasificación Especies.  \
# 0                                                   NaN
# 1                                                    IC
# 2                                                    LC
# 3                                                    IC
# 4                                                   NaN
# ...                                                 ...
# 1449                                                NaN
# 1450                                                NaN
# 1451                                VU(XI-XII), R(VIII)
# 1452                                                 IC
# 1453                                                 EN
#
#      Fuente Categoría ANTERIOR a RCE actual \n(NO VIGENTE)\n(Ver valores en columna adyacente)  \
# 0                                                   NaN
# 1                                                  CAZA
# 2                                RCE 8 (DS 19/2012 MMA)
# 3                                           L_ROJO_Vert
# 4                                                   NaN
# ...                                                 ...
# 1449                                                NaN
# 1450                                                NaN
# 1451                                               CAZA
# 1452                                  Yáñez et al. 1997
# 1453                              RCE9 (DS 13/2013 MMA)
#
#      Categoría ANTE ANTERIOR a RCE actual \n(NO VIGENTE)\nBol_47 = Boletín 47 MNHN\nCAZA  = Reglamento Ley de CAZA\nL_Rojo_Flora = Libro Rojo de flora\nL_Rojo_Vert = Libro Rojo de vertebrados\nNúñez et al. 1997 = Reunión de herpetólogos\nYáñez et al. 1997 = Reunión especialistas mamíferos acuáticos\nRCE = Reglamento de Clasificación Especies.  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                IC\nIC
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1449                                                NaN
# 1450                                                NaN
# 1451                                                NaN
# 1452                                                NaN
# 1453                                                NaN
#
#      Fuente Categoría  ANTE ANTERIOR a RCE actual  \n(NO VIGENTE)\n(Ver valores en columna adyacente)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                     CAZA\nL_ROJO_Vert
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 1449                                                NaN
# 1450                                                NaN
# 1451                                                NaN
# 1452                                                NaN
# 1453                                                NaN
#
#      Es vertebrado, INvertebrado, Planta u Hongo
# 0                                          Planta
# 1                                      Vertebrado
# 2                                      Vertebrado
# 3                                      Vertebrado
# 4                                          Planta
# ...                                           ...
# 1449                                   Vertebrado
# 1450                                       Planta
# 1451                                   Vertebrado
# 1452                                   Vertebrado
# 1453                                       Planta
#
# [1454 rows x 43 columns]

# %% [markdown]
# CARGAR BASE DE DATOS Y DAR ESPECÍFICACIONES PARA FILTRAR

# %%
#Leer datos desde el archivo CSV
datos = pd.read_csv('/content/drive/MyDrive/Excels Gatos Endemicos/ESPECIES (fran).csv')


# Definir mi filtro según la familia a la que pertenecen los gatos que es la FELIDAE (así se diferencian enseguida de los demás datos)
felidae = 'FELIDAE'
felidae2 = 'Felidae'
felidae3 = 'felidae'


# Filtrar los datos para las variables de busqueda
datos_felidae = datos [datos["FAMILIA"].str.contains(felidae) | datos["FAMILIA"].str.contains(felidae2) | datos["FAMILIA"].str.contains(felidae3)]


# Eliminar columnas específicas
columnas_a_eliminar = ['SINONIMIA incompleta', 'PHYLLUM /\nDIVISIÓN']
datos_felidae = datos_felidae.drop(columns=columnas_a_eliminar)

print(datos_felidae)
# Out:
#       ID\nInven\ntario\nNa\ncio\nnal    NOMBRE CIENTÍFICO  \
# 723                             11.0   Leopardus colocolo
# 724                             12.0  Leopardus geoffroyi
# 725                             13.0     Leopardus guigna
# 726                             14.0  Leopardus jacobitus
# 1215                            18.0        Puma concolor
#
#                NOMBRE COMÚN     REINO     CLASE      ORDEN  FAMILIA  \
# 723               colo-colo  Animalia  Mammalia  Carnivora  Felidae
# 724   gato montés argentino  Animalia  Mammalia  Carnivora  Felidae
# 725                   güiña  Animalia  Mammalia  Carnivora  Felidae
# 726      gato montés andino  Animalia  Mammalia  Carnivora  Felidae
# 1215                   puma  Animalia  Mammalia  Carnivora  Felidae
#
#      HÁBITO \n(sólo plantas) ENDÉMICA\nrespecto de Chile \n(? = dudoso)  \
# 723                      NaN                                         NO
# 724                      NaN                                         NO
# 725                      NaN                                         NO
# 726                      NaN                                         NO
# 1215                     NaN                                         NO
#
#      DISTRIBUCIÓN REGIONES:\nANT= ANTARTICA\nDV= DESVENTURADAS\nIP= ISLA DE PASCUA\nJF= Arch. JUAN FERNÁNDEZ\nSG= SALAS Y GOMEZ\n? = Sin datos o de presencia dudosa o requiere confirmación  \
# 723                                               I-XII
# 724                                          IX, XI-XII
# 725                                              IV-XI
# 726                                               XV-II
# 1215                                             XV-XII
#
#       ...  \
# 723   ...
# 724   ...
# 725   ...
# 726   ...
# 1215  ...
#
#      CATEGORÍA VIGENTE:\nCR = En peligro crítico\nDD = Datos insuficientes\nEN = En Peligro\nEW= Extinta en estado silvestre\nEX = Extinta\nFP = Fuera de Peligro\nIC = Insuficientemente Conocida\nLC = Preocupación menor\nNT = Casi amenazada\nR  = Rara\nVU = Vulnerable  \
# 723                                                  NT
# 724                                                  NT
# 725                             VU (XV-XIV), NT (X-XII)
# 726                                                EN-R
# 1215                                                 NT
#
#      FUENTE DE CATEGORÍA VIGENTE:\nCAZA  = Reglamento Ley de CAZA\nRCE = Reglamento de Clasificación Especies.  \
# 723                                                 RCE
# 724                                                 RCE
# 725                                                 RCE
# 726                                                 RCE
# 1215                                                RCE
#
#      Criterio clasificación para especies RCE Vigentes  \
# 723                                                 --
# 724                                                 --
# 725      VU A2c; C2a(i) (XIV al norte);\n- (X  al sur)
# 726                                   EN B2ab(iii); D
# 1215                                                --
#
#      NÚMERO PROCESO RCE  \nse clasificó categoría Vigente  \
# 723                                                   7
# 724                                                   7
# 725                                                   7
# 726                                                   1
# 1215                                                  7
#
#      REFERENCIA o DECRETO\nCategoría Vigente  \
# 723                           DS 42/2011 MMA
# 724                           DS 42/2011 MMA
# 725                           DS 42/2011 MMA
# 726                   DS 151/2007 MINSEGPRES
# 1215                          DS 42/2011 MMA
#
#      Categoría ANTERIOR a RCE actual\n(NO VIGENTE)\nBol_47 = Boletín 47 MNHN\nCAZA  = Reglamento Ley de CAZA\nL_Rojo_Flora = Libro Rojo de flora\nL_Rojo_Vert = Libro Rojo de vertebrados\nNúñez et al. 1997 = Reunión de herpetólogos\nYáñez et al. 1997 = Reunión especialistas mamíferos acuáticos\nRCE = Reglamento de Clasificación Especies.  \
# 723                                                  IC
# 724                                                   R
# 725                                                IC-R
# 726                                                   R
# 1215                             IC(I-VIII), VU(IX-XII)
#
#      Fuente Categoría ANTERIOR a RCE actual \n(NO VIGENTE)\n(Ver valores en columna adyacente)  \
# 723                                               RCE_1
# 724                                               RCE_1
# 725                                               RCE_1
# 726                                                CAZA
# 1215                                        RCE_1, CAZA
#
#      Categoría ANTE ANTERIOR a RCE actual \n(NO VIGENTE)\nBol_47 = Boletín 47 MNHN\nCAZA  = Reglamento Ley de CAZA\nL_Rojo_Flora = Libro Rojo de flora\nL_Rojo_Vert = Libro Rojo de vertebrados\nNúñez et al. 1997 = Reunión de herpetólogos\nYáñez et al. 1997 = Reunión especialistas mamíferos acuáticos\nRCE = Reglamento de Clasificación Especies.  \
# 723                                                  EN
# 724                                                  EN
# 725                                                  EN
# 726                             R [Oreailurus jacobita]
# 1215                           EN(XV-VII), VU(VIII-XII)
#
#      Fuente Categoría  ANTE ANTERIOR a RCE actual  \n(NO VIGENTE)\n(Ver valores en columna adyacente)  \
# 723                                                CAZA
# 724                                                CAZA
# 725                                                CAZA
# 726                                         L_ROJO_Vert
# 1215                                               CAZA
#
#      Es vertebrado, INvertebrado, Planta u Hongo
# 723                                    Vertebrado
# 724                                    Vertebrado
# 725                                    Vertebrado
# 726                                    Vertebrado
# 1215                                   Vertebrado
#
# [5 rows x 41 columns]

# %% [markdown]
# DEFINIR UN DATAFRAME PARA ORDENAR EL FILTRADO (NECESITAMOS 5 FILAS Y 7 COLUMNAS)

# %%
#Importar Libreria

import pandas as pd
import numpy as np

# Cargar y leer datos del archivo CSV
df = pd.read_csv('/content/drive/MyDrive/Excels Gatos Endemicos/ESPECIES (fran).csv', index_col = 0)

df.head ()

#Seleccionamos las columnas especificas
df[['NOMBRE COMÚN', 'NOMBRE CIENTÍFICO', 'REINO', 'CLASE', 'ORDEN', 'FAMILIA', 'DISTRIBUCIÓN REGIONES:\nANT= ANTARTICA\nDV= DESVENTURADAS\nIP= ISLA DE PASCUA\nJF= Arch. JUAN FERNÁNDEZ\nSG= SALAS Y GOMEZ\n? = Sin datos o de presencia dudosa o requiere confirmación']]

#Seleccionamos la categoría FELIDAE que es la FAMILIA a la que pertenecen los gatos estudiados

gatos = df[df['FAMILIA'] == 'Felidae']

gatos.head()
# Out:
#                                   NOMBRE CIENTÍFICO           NOMBRE COMÚN  \
# ID\nInven\ntario\nNa\ncio\nnal
# 11.0                             Leopardus colocolo              colo-colo
# 12.0                            Leopardus geoffroyi  gato montés argentino
# 13.0                               Leopardus guigna                  güiña
# 14.0                            Leopardus jacobitus     gato montés andino
# 18.0                                  Puma concolor                   puma
#
#                                                              SINONIMIA incompleta  \
# ID\nInven\ntario\nNa\ncio\nnal
# 11.0                            Lynchailurus colocolo, Oncifelis colocolo, Fel...
# 12.0                                        Oncifelis geoffroyi,\nFelis geoffroyi
# 13.0                                              Oncifelis guigna,\nFelis guigna
# 14.0                                         Oreailurus jacobita,\nFelis jacobita
# 18.0                                                               Felis concolor
#
#                                    REINO PHYLLUM /\nDIVISIÓN     CLASE  \
# ID\nInven\ntario\nNa\ncio\nnal
# 11.0                            Animalia            Chordata  Mammalia
# 12.0                            Animalia            Chordata  Mammalia
# 13.0                            Animalia            Chordata  Mammalia
# 14.0                            Animalia            Chordata  Mammalia
# 18.0                            Animalia            Chordata  Mammalia
#
#                                     ORDEN  FAMILIA HÁBITO \n(sólo plantas)  \
# ID\nInven\ntario\nNa\ncio\nnal
# 11.0                            Carnivora  Felidae                     NaN
# 12.0                            Carnivora  Felidae                     NaN
# 13.0                            Carnivora  Felidae                     NaN
# 14.0                            Carnivora  Felidae                     NaN
# 18.0                            Carnivora  Felidae                     NaN
#
#                                ENDÉMICA\nrespecto de Chile \n(? = dudoso)  \
# ID\nInven\ntario\nNa\ncio\nnal
# 11.0                                                                   NO
# 12.0                                                                   NO
# 13.0                                                                   NO
# 14.0                                                                   NO
# 18.0                                                                   NO
#
#                                 ...  \
# ID\nInven\ntario\nNa\ncio\nnal  ...
# 11.0                            ...
# 12.0                            ...
# 13.0                            ...
# 14.0                            ...
# 18.0                            ...
#
#                                CATEGORÍA VIGENTE:\nCR = En peligro crítico\nDD = Datos insuficientes\nEN = En Peligro\nEW= Extinta en estado silvestre\nEX = Extinta\nFP = Fuera de Peligro\nIC = Insuficientemente Conocida\nLC = Preocupación menor\nNT = Casi amenazada\nR  = Rara\nVU = Vulnerable  \
# ID\nInven\ntario\nNa\ncio\nnal
# 11.0                                                                           NT
# 12.0                                                                           NT
# 13.0                                                      VU (XV-XIV), NT (X-XII)
# 14.0                                                                         EN-R
# 18.0                                                                           NT
#
#                                FUENTE DE CATEGORÍA VIGENTE:\nCAZA  = Reglamento Ley de CAZA\nRCE = Reglamento de Clasificación Especies.  \
# ID\nInven\ntario\nNa\ncio\nnal
# 11.0                                                                          RCE
# 12.0                                                                          RCE
# 13.0                                                                          RCE
# 14.0                                                                          RCE
# 18.0                                                                          RCE
#
#                                Criterio clasificación para especies RCE Vigentes  \
# ID\nInven\ntario\nNa\ncio\nnal
# 11.0                                                                          --
# 12.0                                                                          --
# 13.0                               VU A2c; C2a(i) (XIV al norte);\n- (X  al sur)
# 14.0                                                            EN B2ab(iii); D
# 18.0                                                                          --
#
#                                NÚMERO PROCESO RCE  \nse clasificó categoría Vigente  \
# ID\nInven\ntario\nNa\ncio\nnal
# 11.0                                                                            7
# 12.0                                                                            7
# 13.0                                                                            7
# 14.0                                                                            1
# 18.0                                                                            7
#
#                                REFERENCIA o DECRETO\nCategoría Vigente  \
# ID\nInven\ntario\nNa\ncio\nnal
# 11.0                                                    DS 42/2011 MMA
# 12.0                                                    DS 42/2011 MMA
# 13.0                                                    DS 42/2011 MMA
# 14.0                                            DS 151/2007 MINSEGPRES
# 18.0                                                    DS 42/2011 MMA
#
#                                Categoría ANTERIOR a RCE actual\n(NO VIGENTE)\nBol_47 = Boletín 47 MNHN\nCAZA  = Reglamento Ley de CAZA\nL_Rojo_Flora = Libro Rojo de flora\nL_Rojo_Vert = Libro Rojo de vertebrados\nNúñez et al. 1997 = Reunión de herpetólogos\nYáñez et al. 1997 = Reunión especialistas mamíferos acuáticos\nRCE = Reglamento de Clasificación Especies.  \
# ID\nInven\ntario\nNa\ncio\nnal
# 11.0                                                                           IC
# 12.0                                                                            R
# 13.0                                                                         IC-R
# 14.0                                                                            R
# 18.0                                                       IC(I-VIII), VU(IX-XII)
#
#                                Fuente Categoría ANTERIOR a RCE actual \n(NO VIGENTE)\n(Ver valores en columna adyacente)  \
# ID\nInven\ntario\nNa\ncio\nnal
# 11.0                                                                        RCE_1
# 12.0                                                                        RCE_1
# 13.0                                                                        RCE_1
# 14.0                                                                         CAZA
# 18.0                                                                  RCE_1, CAZA
#
#                                Categoría ANTE ANTERIOR a RCE actual \n(NO VIGENTE)\nBol_47 = Boletín 47 MNHN\nCAZA  = Reglamento Ley de CAZA\nL_Rojo_Flora = Libro Rojo de flora\nL_Rojo_Vert = Libro Rojo de vertebrados\nNúñez et al. 1997 = Reunión de herpetólogos\nYáñez et al. 1997 = Reunión especialistas mamíferos acuáticos\nRCE = Reglamento de Clasificación Especies.  \
# ID\nInven\ntario\nNa\ncio\nnal
# 11.0                                                                           EN
# 12.0                                                                           EN
# 13.0                                                                           EN
# 14.0                                                      R [Oreailurus jacobita]
# 18.0                                                     EN(XV-VII), VU(VIII-XII)
#
#                                Fuente Categoría  ANTE ANTERIOR a RCE actual  \n(NO VIGENTE)\n(Ver valores en columna adyacente)  \
# ID\nInven\ntario\nNa\ncio\nnal
# 11.0                                                                         CAZA
# 12.0                                                                         CAZA
# 13.0                                                                         CAZA
# 14.0                                                                  L_ROJO_Vert
# 18.0                                                                         CAZA
#
#                                Es vertebrado, INvertebrado, Planta u Hongo
# ID\nInven\ntario\nNa\ncio\nnal
# 11.0                                                             Vertebrado
# 12.0                                                             Vertebrado
# 13.0                                                             Vertebrado
# 14.0                                                             Vertebrado
# 18.0                                                             Vertebrado
#
# [5 rows x 42 columns]

# %% [markdown]
# LOCALIZAR FILAS ESPECÍFICAS Y COLUMNAS ESPECÍFICAS DE LA BASE DE DATOS

# %%
#Importar Libreria
import pandas as pd
import numpy as np


#Leer datos desde el archivo CSV
datos = pd.read_csv('/content/drive/MyDrive/Excels Gatos Endemicos/ESPECIES (fran).csv', index_col = 0)

#Filtrar por filas y columnas específicas

df = pd.DataFrame(datos)
print(df.loc[[11.0, 12.0, 13.0, 14.0, 18.0],['NOMBRE COMÚN', 'NOMBRE CIENTÍFICO', 'REINO', 'CLASE', 'ORDEN', 'FAMILIA', 'DISTRIBUCIÓN REGIONES:\nANT= ANTARTICA\nDV= DESVENTURADAS\nIP= ISLA DE PASCUA\nJF= Arch. JUAN FERNÁNDEZ\nSG= SALAS Y GOMEZ\n? = Sin datos o de presencia dudosa o requiere confirmación']])
# Out:
#                                          NOMBRE COMÚN    NOMBRE CIENTÍFICO  \
# ID\nInven\ntario\nNa\ncio\nnal
# 11.0                                        colo-colo   Leopardus colocolo
# 12.0                            gato montés argentino  Leopardus geoffroyi
# 13.0                                            güiña     Leopardus guigna
# 14.0                               gato montés andino  Leopardus jacobitus
# 18.0                                             puma        Puma concolor
#
#                                    REINO     CLASE      ORDEN  FAMILIA  \
# ID\nInven\ntario\nNa\ncio\nnal
# 11.0                            Animalia  Mammalia  Carnivora  Felidae
# 12.0                            Animalia  Mammalia  Carnivora  Felidae
# 13.0                            Animalia  Mammalia  Carnivora  Felidae
# 14.0                            Animalia  Mammalia  Carnivora  Felidae
# 18.0                            Animalia  Mammalia  Carnivora  Felidae
#
#                                DISTRIBUCIÓN REGIONES:\nANT= ANTARTICA\nDV= DESVENTURADAS\nIP= ISLA DE PASCUA\nJF= Arch. JUAN FERNÁNDEZ\nSG= SALAS Y GOMEZ\n? = Sin datos o de presencia dudosa o requiere confirmación
# ID\nInven\ntario\nNa\ncio\nnal
# 11.0                                                                        I-XII
# 12.0                                                                   IX, XI-XII
# 13.0                                                                       IV-XI
# 14.0                                                                        XV-II
# 18.0                                                                       XV-XII
